# %%
# !/usr/bin/env python3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rng = pd.date_range('1/1/2018', periods=72, freq='H')
rng.dtype
# Out:
# dtype('<M8[ns]')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
fig,ax = plt.subplots(figsize=(20,10))
ax.plot(rng, ts)

# %%
pd.Timestamp(pd.datetime(2018,12,10))
# Out:
# Timestamp('2018-12-10 00:00:00')

# %%
pd.Timestamp('2018.12.10')
# Out:
# Timestamp('2018-12-10 00:00:00')

# %%
pd.Timestamp('2018-12-10')
# Out:
# Timestamp('2018-12-10 00:00:00')

# %%
pd.Period('2018-05', 'D')
# Out:
# Period('2018-05-01', 'D')

# %%
pd.to_datetime(pd.Series(['2018.3.10', '2018-12-10', None]))
# Out:
# 0   2018-03-10
# 1   2018-12-10
# 2          NaT
# dtype: datetime64[ns]

# %%
dates = [pd.datetime(2018,12,10), pd.datetime(2018,12,11),pd.datetime(2018,12,12)]

# %%
index = pd.DatetimeIndex(dates)

# %%
index
# Out:
# DatetimeIndex(['2018-12-10', '2018-12-11', '2018-12-12'], dtype='datetime64[ns]', freq=None)

# %%
index = pd.date_range('2018-1-2', periods=1000, freq='D')

# %%
index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-06', '2018-01-07', '2018-01-08', '2018-01-09',
#                '2018-01-10', '2018-01-11',
#                ...
#                '2020-09-18', '2020-09-19', '2020-09-20', '2020-09-21',
#                '2020-09-22', '2020-09-23', '2020-09-24', '2020-09-25',
#                '2020-09-26', '2020-09-27'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
pd.datetime.year
# Out:
# <attribute 'year' of 'datetime.date' objects>

# %%
date = pd.datetime(2018,12,11)

# %%
date.strftime('%w')
# Out:
# '2'

# %%
date = '20170601'

# %%
pd.Timestamp(date)
# Out:
# Timestamp('2017-06-01 00:00:00')

# %%
import pandas as pd
dates = ['2015-12-20','2015-09-12']  
PM_25 = [80, 55]
dates = [pd.to_datetime(d) for d in dates]

plt.scatter(dates, PM_25, s =100, c = 'red')
