# %%
import pandas as pd
file = '/home1/shenxing/rasa_bert_nlu/data/bert_data/spell_checker_result_Yiwise_data.txt'
Data = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-1-a1102c024eba> in <module>
#       1 import pandas as pd
#       2 file = '/home1/shenxing/rasa_bert_nlu/data/bert_data/spell_checker_result_Yiwise_data.txt'
# ----> 3 Data = pd.read_csv(file)
#
# ...

# %%
text = '嗯，我们营业网点在宝安区中粮地产集团中心这边，我稍后加您微信给您发个定位！'
print(text)
new_text = text.replace(",","。")
print(new_text)
# Out:
# 嗯，我们营业网点在宝安区中粮地产集团中心这边，我稍后加您微信给您发个定位！
# 嗯，我们营业网点在宝安区中粮地产集团中心这边，我稍后加您微信给您发个定位！

# %%
print(textxt)

# %%
text.replace(",","，")
# Out:
# '嗯，我们营业网点在宝安区中粮地产集团中心这边，我稍后加您微信给您发个定位！'

# %%
print(Data[Data['correct']==False])
# Out:
#                     text init_word  init_score max_word  max_score  \
# 883                 套餐一吧         吧   -6.657935        般  -5.888999
# 921        给我办一下便宜点的流量套餐         给   -6.052592        行  -5.778663
# 1026                   喂         喂  -10.410656        一  -5.585598
# 3665  喂 请 本月 18006208658         喂   -8.384805        一  -7.530041
# 6628     喂 帮我 开一个 二十八 业务         喂   -6.328299        一  -5.061514
# 7165      喂 给我 办一下 便宜 业务         喂   -6.830817        一  -5.317158
# 8632              业务 一 吧         业   -5.077481        是  -5.032713
# 8635              业务 一 吧         吧  -11.897801        般  -6.694063
# 8702                业务 三         业   -5.254399        是  -5.021414
# 8723              套餐 一 吧         吧   -6.657935        般  -5.888999
# 8750              业务 二 吧         业   -5.182066        是  -5.123833
# 8868                   喂         喂  -10.410656        一  -5.585598
#
#      second_word  second_score  score_diff  correct
# ...

# %%
D = Data[Data['score_diff']>1]

# %%
D2 = D[D['second_word']!="None"]

# %%
D2
# Out:
#                  text init_word  init_score max_word  max_score second_word  \
# 0        帮我查一下我的流量有多少         帮   -0.059504        帮  -0.059504           榜
# 1        帮我查一下我的流量有多少         我   -0.000021        我  -0.000021           窝
# 2        帮我查一下我的流量有多少         查   -0.000133        查  -0.000133           察
# 3        帮我查一下我的流量有多少         一   -0.000664        一  -0.000664           壹
# 4        帮我查一下我的流量有多少         下   -0.000016        下  -0.000016           些
# 5        帮我查一下我的流量有多少         我   -0.000011        我  -0.000011           窝
# 6        帮我查一下我的流量有多少         的   -0.000021        的  -0.000021           地
# 7        帮我查一下我的流量有多少         流   -0.000010        流  -0.000010           路
# 8        帮我查一下我的流量有多少         量   -0.000010        量  -0.000010           粮
# 9        帮我查一下我的流量有多少         有   -0.000113        有  -0.000113           又
# 10       帮我查一下我的流量有多少         多   -0.000011        多  -0.000011           都
# ...
